# %% [markdown]
# <a href="https://colab.research.google.com/github/HaniaArif/Python-Data-Structures/blob/main/exploring_python_stacks_and_queues.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Stacks
#
# Just look at the stack of books in your school library!!! That's a huge stack right... Let's say you are hired to manage your local library and you want to stack all the books in alphabetical order. So... what you would do is you just make a stack of all the books such that the ones starting with 'A' go at the bottom of the stack while the one starting with 'B' go on top of that... 📚
#
# Now, a person comes in and he wants to have the book starting with the letter 'A', so for getting that book you would have to remove the letter 'B' books in order to reach the letter 'A' book. 📘📗📙
#
# Now... the library has got some funds and as you are really good at stacking the books, they asked you to make a system which can stack the books in the same way... 🙃
#
#
#
# ---

# %% [markdown]
# Now, let's make a stack in our code so that no one can get anybook out of sequence by just pulling a book from the center... Otherwise your whole stack of books will fall on his head right! 😵
#
# ✅ You can use any build in data-structure for making a stack, you would then just have to use the build in functions related to that data-structure carefully...
#
# 🤔 So, can we use a dictionary too?
#
# ✅ Yes, You can use a dictionary as well in order to make a stack. But use it only if you want to save a group of data at the same time like if you want to save the data of 1000 people in the form of a stack and you have to save the name, age, salary, hobby of that person, you would need to use a dictionary so that you would be able to save all that data with one key...
#
# ✅ if you don't want to use the dictionaries, you can also use a nested list if you want to save a group of data at the same time...
#
# 😎 See... you can make the code with which ever thing you like... but you just have to think of a few things before using any data-structure like 👀
#
# ⚡ How much memory space will one item use to be saved?
#
# ⚡ How much items do you want to save?

# %%
class Book_stack:
  def __init__(self, book_name):
    #make a list to save all the books
    self.books_list = []
    #save the book
    self.books_list.append(book_name)

# %% [markdown]
# Now, let's try to add a book in our stack of books:

# %%
my_book_stack = Book_stack("The horror of operating systems!")

# %% [markdown]
# 🤔 But... if you were making a system... then how would you know if the book has been successfully added to the stack or not?
#
# Let's add a message function in our stack...

# %%
class Book_stack:
  def __init__(self, book_name):
    #make a list to save all the books
    self.books_list = []
    #save the book
    self.books_list.append(book_name)

    #-----CHECK THIS OUT-----
    self.show_success_message(book_name)      #don't forget to add 'self' in the start of the function name
    #------------------------

  def show_success_message(self, book_name):
    print("Your book", book_name, "has been added to the book stack")

# %% [markdown]
# Now... let's try to add the book again to check if our stack shows a success message or not.

# %%
my_book_stack = Book_stack("The horror of operating systems!")
# Out:
# Your book The horror of operating systems! has been added to the book stack

# %% [markdown]
# 🤔 But what if we want to add more and more books in our stack... Let's add a function for that...

# %%
class Book_stack:
  def __init__(self, book_name):
    #make a list to save all the books
    self.books_list = []
    #save the book
    self.books_list.append(book_name)
    self.show_success_message(book_name)

  #-----CHECK THIS OUT-----
  def add_book_to_stack(self, book_name):
    self.books_list.append(book_name)
    self.show_success_message(book_name)
  #------------------------

  def show_success_message(self, book_name):
    print("Your book", book_name, "has been added to the book stack")

# %% [markdown]
# Now... Let's try to add a few more horror books to our stack of books!!! 👻

# %%
#STEP 1 - create a stack
my_book_stack = Book_stack("The horror of operating systems!")

#STEP 2 - add more and more books to your stack
my_book_stack.add_book_to_stack("The crazy numerical methods in programming")
my_book_stack.add_book_to_stack("Successful turtle stories - while it goes Left on your Python IDE")

# %% [markdown]
# Now, our stack is all ready... it's time to remove a book from the stack...

# %%
class Book_stack:
  def __init__(self, book_name):
    #make a list to save all the books
    self.books_list = []
    #save the book
    self.books_list.append(book_name)
    self.show_success_message(book_name)

  
  def add_book_to_stack(self, book_name):
    self.books_list.append(book_name)
    self.show_success_message(book_name)

  #-----CHECK THIS OUT-----
  def remove_book(self):
    removed_book = self.books_list.pop()
    return removed_book
  #------------------------

  def show_success_message(self, book_name):
    print("Your book", book_name, "has been added to the book stack")

# %% [markdown]
# Now, let's try to remove some books

# %%
#STEP 1 - create a stack
my_book_stack = Book_stack("The horror of operating systems!")

#STEP 2 - add more and more books to your stack
my_book_stack.add_book_to_stack("The crazy numerical methods in programming")
my_book_stack.add_book_to_stack("Successful turtle stories - while it goes Left on your Python IDE")

#STEP 3 - remove some books
removed_book = my_book_stack.remove_book()
print("Your book", removed_book, "has been removed from the stack")

# %% [markdown]
# ✅ for book addition or removal, you can even create a message function in the book stack if you like... or you can simply use a print statement... which ever you prefer... but the important thing is 👀 Do add different messages for the user whenever you are making a system.
#
# ⚡ It would make it easy for you to debug.
#
# ⚡ It would make it easy for the user to understand what's hapenning in the system.

# %% [markdown]
# ---
#
# #Queues 🚌🚌🚌

# %% [markdown]
# Queues are quite similar to stack... but wait!... what's the difference if both are similar! 😵
#
# The onely difference is that the thing which goes into your data-structure first, comes out i.e. pops out first...

# %% [markdown]
# Let's say you are standing at the back of a Cola Vending machine and restocking it... and you put in some cans of Cola from the back side of the vending machine... So, if some customer comes in and presses the cola button, the can you put in the vending machine first, will be given to the customer.
#
# Let's make a Cola Vending Machine...

# %%
#totally same as stacks

class cola_machine:
  def __init__(self, cola_can):
    #make a list to save all the books
    self.cola_list = []
    #save the book
    self.cola_list.append(cola_can)
    self.show_success_message(cola_can)

  
  def add_can_to_machine(self, cola_can):
    self.cola_list.append(cola_can)
    self.show_success_message(cola_can)

  #-----CHECK THIS OUT-----
  def remove_can(self):
    removed_can = self.cola_list.pop(0)
    return removed_can
  #------------------------

  def show_success_message(self, cola_can):
    print("Your can", cola_can, "has been added to the cola can queue")

# %% [markdown]
# If you see 👀 the ony change made in the queue is the remove function where we always pop(0).
#
# See that was simple... 😎
#
# Now, let's try to add and remove cola cans from our cola vending machine

# %%
#STEP 1 - create a stack
cola_queue = cola_machine("Cola Can 1")

#STEP 2 - add more and more books to your stack
cola_queue.add_can_to_machine("Cola Can 2")
cola_queue.add_can_to_machine("Cola Can 3")

#STEP 3 - remove some books
removed_can = cola_queue.remove_can()
print(removed_can, "has been removed from the cola machine")

# %% [markdown]
# #Summary

# %% [markdown]
# ![IMAGE 9.png](data:image/png;base64,...)

# %% [markdown]
# #To Do:
# You can try to make this stack by using numbers...
# ![image1.png](data:image/png;base64,...)
